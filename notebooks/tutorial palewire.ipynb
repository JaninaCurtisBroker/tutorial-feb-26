# %%
## Make sure we're using the right kernel - the one in our virtual environment. (Also make sure we have python in the virtual environment)
import sys
print(sys.executable)
# Out:
# c:\Users\JBroker\Python projects\janina\tutorial-feb-06\venv\Scripts\python.exe
