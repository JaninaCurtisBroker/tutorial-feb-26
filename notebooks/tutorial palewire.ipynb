# %%
my_list = [2, 4, 6, 8]
len(my_list)
sum(my_list)/len(my_list)
# Out:
# 5.0

# %%
import pandas as pd
import IPython
(IPython.__version__, sys.executable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 import IPython
# ----> 3 (IPython.__version__, sys.executable)
#
# NameError: name 'sys' is not defined

# %%
## Make sure we're using the right kernel - The Jupyter kernel is what determines which Python environment the notebook runs in.
import sys
print(sys.executable)
# Out:
# c:\Users\JBroker\Python projects\janina\tutorial-feb-06\venv\Scripts\python.exe
